# %% [markdown]
# # 이미지 띄우기

# %%
# %pip install numpy
# %pip install opencv-python
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/c7/ec/9dabb6a9abfdebb3c45b0cc52dec901caafef2b2c7e7d6a839ed86d81e91/opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#     --------------------------------------- 0.9/38.6 MB 29.4 MB/s eta 0:00:02
#    -- ------------------------------------- 2.8/38.6 MB 36.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 4.0/38.6 MB 32.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 5.6/38.6 MB 32.3 MB/s eta 0:00:02
#    ------- -------------------------------- 6.8/38.6 MB 31.0 MB/s eta 0:00:02
#    -------- ------------------------------- 8.7/38.6 MB 32.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 10.6/38.6 MB 34.6 MB/s eta 0:00:01
# ...

# %%
#코드에 대한 설명을 작성하세요.

import numpy as np
import cv2                         #컴퓨터 비전 관련 라이브러리 가져오기

img = cv2.imread('card.png')        #이미지를 읽어와서 img에 담아주는 코드

cv2.imshow('window title', img)              #이미지를 window title 이라는 제목의 창으로 띄워줌
cv2.waitKey(0)                      #n초 만큼 키보드 입력을 기다림(단, 0일시 영원히 기다림)
cv2.destroyAllWindows()             #모든 창 닫기

# %% [markdown]
# # 도형그리기
# ![image.png](attachment:image.png)
#
# - 검색창에 opencv circle documentation 를 검색해서 공식 문서로 사용법을 확인해보세요.

# %%
# 원 그리기
import numpy as np
import cv2

img = cv2.imread('card.png')
y, x , _= img.shape                #
# 위의 그림처럼 원을 그려보세요.
img = cv2.circle(img, (x//2, y//2), 250, (255, 0, 0), 6)
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Q. 위의 코드에 코드를 추가하여 그림과 같이 만들어보세요.
# - 반지름 15인 파란색 원 4개, 초록색 직선 4개
# - 크기3, 굵기5, 빨간색 텍스트
# ![image-4.png](attachment:image-4.png)

# %%
import numpy as np
import cv2

img = cv2.imread('card.png')

# 원4개 그리기
circle = [(240, 150),
(600, 320),
(470, 520),
(100, 330),]
for xy in circle:
    cv2.circle(img, xy, 15, (255, 0, 0), -1)
# 직선 4개 그리기
for i in range(4):
    cv2.line(img, circle[i], circle[(i+1)%4], (0, 255, 0), 6)
# 텍스트 작성하기
cv2.putText(img, "CreditCard", (0, y-10), 5, 3, (0, 0, 255), 3)
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 원근법
# ![image.png](attachment:image.png)

# %%
#주석을 작성해보세요.

import numpy as np
import cv2

img = cv2.imread('card.png')

width, height = (350, 180)                                                             #
circle = [[238, 149], [600, 320], [473, 520], [97, 329]]                              # 

src = np.array(circle, dtype = np.float32)                                            #
dst = np.array([[0,0],[width, 0], [width, height], [0, height]] , dtype = np.float32) #

matrix = cv2.getPerspectiveTransform(src, dst)                                         # 
result = cv2.warpPerspective(img, matrix, (width, height))                              # 

cv2.imshow('img', img)
cv2.imshow('result', result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 마우스 콜백(MouseCallback)
# - 예시코드) https://docs.opencv.org/4.x/db/d5b/tutorial_py_mouse_handling.html
# - opencv mouse callback python 를 검색하여 공식문서를 확인해보세요.

# %% [markdown]
# ### 아래의 코드를 실행하고, 각 코드가 하는 기능을 예상해 주석을 작성해보세요.

# %%
import numpy as np
import cv2 as cv

# mouse callback function
def draw_circle(event,x,y,flags,param):                                   #
 if event == cv.EVENT_LBUTTONDBLCLK:                                      #
     cv2.circle(img,(x,y),100,(255,0,0),-1)                               #
        
# Create a black image, a window and bind the function to window
img = np.zeros((512,512,3), np.uint8)                                     #
cv2.namedWindow('image')                                                  #
cv2.setMouseCallback('image',draw_circle)                                 #

while(1):                                                                #
 cv2.imshow('image',img)
 if cv.waitKey(20) & 0xFF == 27:                                        #
     break        
cv2.destroyAllWindows()

# %% [markdown]
# ### Q.위의 코드를 수정해서 업그레이드 해보세요.
# - 왼쪽버튼 더블클릭하면 원그리고, 오른쪽버튼 더블클릭하면 정사각형 그리기
# - 정사각형조건: 주황색(0, 95, 255), 한변의 길이는 100
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
import cv2 as cv
# mouse callback function
def draw_circle(event,x,y,flags,param):
 if event == cv2.EVENT_LBUTTONDBLCLK:
     cv2.circle(img,(x,y),100,(255,0,0),-1)
 elif #여기에 코드를 작성해보세요.

        
# Create a black image, a window and bind the function to window
img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_circle)

while(1):
 cv2.imshow('image',img)
 if cv.waitKey(20) & 0xFF == 27:
     break
cv2.destroyAllWindows()

# %% [markdown]
# ### Q.아래의 코드를 보고 결과를 예상해보세요.

# %%
import numpy as np
import cv2 as cv

drawing = False                   # 마우스가 클릭되면 True 로 바뀜.
mode = True                       # 키보드'm'을 누르면 바뀜. True면 사각형, False면 커브그리기.
ix,iy = -1,-1

# mouse callback function
def draw_circle(event,x,y,flags,param):
 global ix,iy,drawing,mode
 if event == cv.EVENT_LBUTTONDOWN:
     drawing = True
     ix,iy = x,y
 elif event == cv.EVENT_MOUSEMOVE:
     if drawing == True:
         if mode == True:
             cv.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)
         else:
             cv.circle(img,(x,y),5,(0,0,255),-1)
 elif event == cv.EVENT_LBUTTONUP:
        drawing = False
        if mode == True:
                 cv.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)
        else:
                 cv.circle(img,(x,y),5,(0,0,255),-1)

# %%
img = np.zeros((512,512,3), np.uint8)
cv.namedWindow('image')
cv.setMouseCallback('image',draw_circle)

while(1):
 cv.imshow('image',img)
 k = cv.waitKey(1) & 0xFF
 if k == ord('m'):
     mode = not mode
 elif k == 27:
     break
cv.destroyAllWindows()

# %% [markdown]
# ### 이미지에서 클릭한 지점의 좌표 저장 및 원그리기
# - 원크기: 13, 색: 빨강색
#
#
# ![image.png](attachment:image.png)

# %%
import numpy as np

point_list = []
img = cv2.imread('card.png')

def get_points(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        point_list.append([x, y])
        cv2.circle(img, (x,y), 13, (0,0,255), cv2.FILLED)
    cv2.imshow('img', img)
        
cv.namedWindow('img')
cv.imshow('img',img)

cv.setMouseCallback('img',get_points)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
print(point_list)
# Out:
# [[249, 150], [107, 333], [473, 512], [596, 326]]

# %% [markdown]
# # 이미지 사이즈 변경

# %%
result.shape
# Out:
# (180, 350, 3)

# %%
# 고정 크기를 이용해 작게(160, 90), 크게(480, 270) 바꾸기
import numpy as np
import cv2

small= cv2.resize(result, (160, 90))
large = cv2.resize(result, (850, 550))

cv2.imshow('small', small)
cv2.imshow('large', large)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 비율설정으로 작게(*0.5) 크게(*3) 바꾸기
import numpy as np
import cv2

small= cv2.resize(result, None, fx = 0.5, fy = 0.5)
large = cv2.resize(result,  None, fx = 3, fy = 3)

cv2.imshow('small', small)
cv2.imshow('large', large)

cv2.waitKey(0)
cv2.destroyAllWindows()
